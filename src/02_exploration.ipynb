# %% [markdown]
# import pandas as pd
# from database_helper import Database

# %%
from database_helper import Database
import pandas as pd

from venn import venn
# %matplotlib inline
db = Database('/Users/alessiogandelli/data_social_dynamics/social_dynamics.sqlite')

# %% [markdown]
# # Missing userid exploration

# %% [markdown]
# ## get all userid from each dataset

# %%
td_userid = db.query("select distinct userid from diary")
socio_userid = db.query("select distinct userid from socio")
loc_userid = db.query("select distinct userid from location")
not_userid = db.query("select distinct userid from notification")
app_userid = db.query("select distinct userid from application")
touch_userid = db.query("select distinct userid from touch")
screen_userid = db.query("select distinct userid from screen")

td_userid = set([i[0] for i in td_userid])
socio_userid = set([i[0] for i in socio_userid])
loc_userid = set([i[0] for i in loc_userid])
not_userid = set([i[0] for i in not_userid])
app_userid = set([i[0] for i in app_userid])
touch_userid = set([i[0] for i in touch_userid])

# %%
screen_userid = db.query("select distinct userid from screen")
screen_userid = set([i[0] for i in screen_userid])

# %% [markdown]
# ## Some set operations

# %%
all_userid = td_userid | socio_userid | loc_userid | not_userid | app_userid | touch_userid | screen_userid

td_missing = all_userid - td_userid
socio_missing = all_userid - socio_userid
loc_missing = all_userid - loc_userid
not_missing = all_userid - not_userid
app_missing = all_userid - app_userid
touch_missing = all_userid - touch_userid
screen_missing = all_userid - screen_userid

missing_all_sensors = loc_missing & not_missing & app_missing & touch_missing & screen_missing

some_sensors_userid = all_userid - missing_all_sensors # remove missing all sensors 


useful_td_missing = some_sensors_userid - td_userid
useful_socio_missing = some_sensors_userid - socio_userid

useful_userid = some_sensors_userid - useful_td_missing - useful_socio_missing # remove missing from td and socio

useful_loc_missing = useful_userid - loc_userid
useful_not_missing = useful_userid - not_userid
useful_app_missing = useful_userid - app_userid
useful_touch_missing = useful_userid - touch_userid
useful_screen_missing = useful_userid - screen_userid

# %%
print('there are '+str(len(all_userid))+ ' users')
print( 'there are '+ str(len(td_userid & socio_userid & loc_userid & not_userid & app_userid & touch_userid)) + ' users with all data')

print('\nthere are '+str(len(td_userid))+ ' users with diary data')
print('there are '+str(len(socio_userid))+ ' users with socio data')
print('there are '+str(len(loc_userid))+ ' users with location data')
print('there are '+str(len(not_userid))+ ' users with notification data')
print('there are '+str(len(app_userid))+ ' users with application data')
print('there are '+str(len(touch_userid))+ ' users with touch data')
print('there are '+str(len(screen_userid))+ ' users with screen data')


print('\nthere are '+str(len(td_missing))+ ' users with missing time diary')
print('there are '+str(len(socio_missing))+ ' users with missing socio')
print('there are '+str(len(loc_missing))+ ' users with missing location')
print('there are '+str(len(not_missing))+ ' users with missing notification')
print('there are '+str(len(app_missing))+ ' users with missing application')
print('there are '+str(len(touch_missing))+ ' users with missing touch')
print('there are '+str(len(screen_missing))+ ' users with missing screen')

print( '\nthere are '+str(len(missing_all_sensors)+len(useful_td_missing) + len(useful_socio_missing))+ ' users with missing all sensors data or time diary or socio')


print('from the remaining '+str(len(useful_userid))+' users, '+str(len(useful_loc_missing))+' have missing location data')
print('from the remaining '+str(len(useful_userid))+' users, '+str(len(useful_not_missing))+' have missing notification data')
print('from the remaining '+str(len(useful_userid))+' users, '+str(len(useful_app_missing))+' have missing application data')
print('from the remaining '+str(len(useful_userid))+' users, '+str(len(useful_touch_missing))+' have missing touch data')
print('from the remaining '+str(len(useful_userid))+' users, '+str(len(useful_screen_missing))+' have missing screen data')
# Out:
# there are 252 users
# there are 169 users with all data
#
# there are 241 users with diary data
# there are 249 users with socio data
# there are 221 users with location data
# there are 183 users with notification data
# there are 234 users with application data
# there are 201 users with touch data
# there are 234 users with screen data
#
# there are 11 users with missing time diary
# there are 3 users with missing socio
# there are 31 users with missing location
# there are 69 users with missing notification
# there are 18 users with missing application
# there are 51 users with missing touch
# there are 18 users with missing screen
#
# there are 21 users with missing all sensors data or time diary or socio
# from the remaining 231 users, 13 have missing location data
# from the remaining 231 users, 49 have missing notification data
# from the remaining 231 users, 0 have missing application data
# from the remaining 231 users, 33 have missing touch data
# from the remaining 231 users, 0 have missing screen data

# %% [markdown]
# ## visualize missing users

# %% [markdown]
# touch and application are the same
# if someone does not share touch then does not share anything

# %%
print(len(useful_loc_missing | useful_not_missing | useful_touch_missing), 'users have missing data from at least one sensor')
print(len(useful_not_missing  & useful_touch_missing), 'miss both notification and touch')
venn({'missing location': useful_loc_missing, 'missig notification': useful_not_missing, 'missing touch' : useful_touch_missing})
venn({'all': all_userid, 'useful' : useful_userid, 'missing all sensors' : missing_all_sensors})
# Out:
# 62 users have missing data from at least one sensor
# 23 miss both notification and touch
# <AxesSubplot: >

# %% [markdown]
# # in depth table analysis
# once i have defined the useful users i can now explore which data is missing in the time diaries and socio tables

# %% [markdown]
# ## socio

# %% [markdown]
# ## time diary

# %%
df = pd.read_sql_query("select * from diary", db.connection)
df = df.loc[df['userid'].isin(useful_userid)]

# %% [markdown]
# the data seems complete, there are 1114 records for each users

# %%
#max rows to show
pd.set_option('display.max_rows', 500)

df.groupby('userid').count().sort_values('userid')
# Out:
#         timestamp  first2w  week  what  travel  travel_medium  sport  where  \
# userid
# 0            1114     1114  1114  1114      15             15      2   1114
# 1            1114     1114  1114  1114       6              6      4   1114
# 2            1114     1114  1114  1114      12             12      3   1114
# 3            1114     1114  1114  1114      16             16      0   1114
# 4            1114     1114  1114  1114       4              4     25   1114
# 5            1114     1114  1114  1114       7              7      7   1114
# 6            1114     1114  1114  1114       0              0      7   1114
# 7            1114     1114  1114  1114       0              0      0   1114
# 8            1114     1114  1114  1114       0              0      0   1114
# 9            1114     1114  1114  1114       0              0      8   1114
# 10           1114     1114  1114  1114       0              0      4   1114
# 12           1114     1114  1114  1114       5              5      5   1114
# 13           1114     1114  1114  1114      17             17      0   1114
# 14           1114     1114  1114  1114       0              0      0   1114
# 15           1114     1114  1114  1114      10             10      7   1114
# 17           1114     1114  1114  1114       0              0      2   1114
# 18           1114     1114  1114  1114       0              0      1   1114
# 19           1114     1114  1114  1114       2              2     54   1114
# 20           1114     1114  1114  1114       0              0      1   1114
# 21           1114     1114  1114  1114      32             32     11   1114
# 22           1114     1114  1114  1114       0              0     16   1114
# 23           1114     1114  1114  1114       2              2      1   1114
# 2020-11-28    11184
# 2020-11-29    11184
# 2020-11-30     7922
# 2020-12-01     5592
# 2020-12-02     5592
# 2020-12-03     5592
# 2020-12-04     5592
# 2020-12-05     5592
# 2020-12-06     5592
# 2020-12-07     5592
# 2020-12-08     5592
# 2020-12-09     5592
# 2020-12-10     5592
# 2020-12-11     5592
# Name: userid, dtype: int64

# %%
#max rows to show
pd.set_option('display.max_rows', 500)
df.groupby(['time'])['userid'].count().plot()
# Out:
# <AxesSubplot: xlabel='time'>

# %% [markdown]
# ## touch

# %%
df = pd.read_sql_query("select * from touch where userid = 234", db.connection)

# %%
import datetime

df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
#group the dataframe by hour
# bar plot pandas 

df.groupby(df['timestamp'].dt.day)['userid'].count().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='timestamp'>

# %%
df.groupby(df['timestamp'].dt.hour)['userid'].count().plot(kind='bar')
df.groupby(df['timestamp'].dt.minute)['userid'].count().plot(kind='bar')

# %%
df = pd.read_sql_query("select count(userid) from touch group by strftime( '%H', timestamp) " , db.connection)

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df = pd.read_sql_query("select count(userid) from touch group by strftime( '%H%M', timestamp) " , db.connection)

# %%
df.plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## notification

# %%
df = pd.read_sql_query("select  count(nontificationid) from notification group  by userid  " , db.connection)

# %%
df.plot(kind='bar', figsize=(20,10))
#sort df values
# Out:
# <AxesSubplot: >

# %%
df = pd.read_sql_query("select  count(nontificationid) from notification group  by strftime( '%H', timestamp)  " , db.connection)

# %%
df.plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
df = pd.read_sql_query("select  count(nontificationid) from notification group  by strftime( '%M', timestamp)  " , db.connection)

# %%
df.plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
df = pd.read_sql_query("select  count(nontificationid) from notification group  by strftime( '%d', timestamp)  " , db.connection).plot(kind='bar', figsize=(20,10))

# %% [markdown]
# ## application

# %%
df = pd.read_sql_query("select userid, application, time from application where userid = 234 " , db.connection)

# %%
df.groupby('application').count().sort_values('userid', ascending=False).head(10)
# Out:
#                                   userid   time
# application
#                                    23190  23190
# com.huawei.android.launcher        13816  13816
# com.google.android.youtube          7799   7799
# com.instagram.android               4911   4911
# org.telegram.messenger              3015   3015
# com.android.chrome                  2090   2090
# com.whatsapp                        1916   1916
# com.riotgames.legendsofruneterra     830    830
# it.unitn.disi.witmee.sensorlog       715    715
# com.android.incallui                 666    666

# %%
df['hour'] = pd.to_datetime(df['time']).dt.hour
df['min'] = pd.to_datetime(df['time']).dt.minute
df['sec'] = pd.to_datetime(df['time']).dt.second

# %%
df1 = df.groupby(['hour','min']).count().sort_values(['hour','min'])
pd.set_option('display.max_rows', 500)

#groupby hour and compute the mean and std
df1.reset_index(inplace=True)
df1.groupby('min')['userid'].agg(['mean','std'])

#df[df['min'] == 1].groupby('hour')['userid'].count().plot(kind='bar')

df.query('min == 12 & hour == 22')
df.sort_values('time', ascending=False).head(100) 
df.query('application != "com.huawei.android.launcher" & application != "" & application != "it.unitn.disi.witmee.sensorlog"').sort_values(['time']).groupby(['hour', 'min'])['application'].apply(lambda x: x.value_counts().index[0]).reset_index().head(500)


#max rows to show
#df.groupby(['hour','min']).agg({'sec': ['mean', 'std']}).sort_values(['hour','min'])
# Out:
#      hour  min                       application
# 0       0    1        com.google.android.youtube
# 1       0    2        com.google.android.youtube
# 2       0    3        com.google.android.youtube
# 3       0    4        com.google.android.youtube
# 4       0    5        com.google.android.youtube
# 5       0    6        com.google.android.youtube
# 6       0    7        com.google.android.youtube
# 7       0    8        com.google.android.youtube
# 8       0    9        com.google.android.youtube
# 9       0   10        com.google.android.youtube
# 10      0   11        com.google.android.youtube
# 11      0   12        com.google.android.youtube
# 12      0   13        com.google.android.youtube
# 13      0   14        com.google.android.youtube
# 14      0   15        com.google.android.youtube
# 15      0   16        com.google.android.youtube
# 16      0   17        com.google.android.youtube
# 17      0   18        com.google.android.youtube
# 18      0   19        com.google.android.youtube
# 19      0   20        com.google.android.youtube
# 20      0   21        com.google.android.youtube
# 21      0   22            org.telegram.messenger
# 22      0   23            org.telegram.messenger
# 23      0   24            org.telegram.messenger
# 24      0   25            org.telegram.messenger
# 25      0   26            org.telegram.messenger
# 26      0   27            org.telegram.messenger
# 27      6   35                      com.whatsapp
# 28      7   23            org.telegram.messenger
# 29      7   24            org.telegram.messenger
# 30      7   30        com.google.android.youtube
# 31      7   31        com.google.android.youtube
# 32      7   33             com.instagram.android
# 33      7   34             com.instagram.android
# 34      7   35             com.instagram.android
# 35      7   36             com.instagram.android
# 36      7   37             com.instagram.android
# 37      7   38             com.instagram.android
# 38      7   39             com.instagram.android
# 39      7   40             com.instagram.android
# 40      7   41             com.instagram.android
# 41      7   42             com.instagram.android
# 42      7   43                      com.whatsapp
# 43      7   46             com.instagram.android
# 44      7   47             com.instagram.android
# 45      7   48             com.instagram.android
# 46      7   49             com.instagram.android
# 47      7   50             com.instagram.android
# 48      7   51             com.instagram.android
# 49      7   52             com.instagram.android
# 50      7   53             com.instagram.android
# 51      7   54             com.instagram.android
# 52      7   55  com.riotgames.legendsofruneterra
# 53      7   56  com.riotgames.legendsofruneterra
# 54      7   57  com.riotgames.legendsofruneterra
# 55      7   58                      com.whatsapp
# 56      7   59            org.telegram.messenger
# 57      8    0                com.android.chrome
# 58      8    1                com.android.chrome
# 59      8    2                com.android.chrome
# 60      8    3                com.android.chrome
# 61      8    4                com.android.chrome
# 62      8    5             com.android.deskclock
# 63      8    6                com.android.chrome
# 64      8    7                com.android.chrome
# 65      8    8            org.telegram.messenger
# 66      8    9                com.android.chrome
# 67      8   10        com.google.android.youtube
# 68      8   11                com.android.chrome
# 69      8   12                com.android.chrome
# 70      8   13                com.android.chrome
# 71      8   14        com.google.android.youtube
# 72      8   15                com.android.chrome
# 73      8   16                com.android.chrome
# 74      8   17                com.android.chrome
# 75      8   18                com.android.chrome
# 76      8   19                      com.duolingo
# 77      8   20  com.riotgames.legendsofruneterra
# 78      8   21  com.riotgames.legendsofruneterra
# 79      8   22  com.riotgames.legendsofruneterra
# 80      8   23        com.google.android.youtube
# 81      8   24        com.google.android.youtube
# 82      8   25        com.google.android.youtube
# 83      8   26        com.google.android.youtube
# 84      8   27  com.riotgames.legendsofruneterra
# 85      8   28  com.riotgames.legendsofruneterra
# 86      8   29        com.google.android.youtube
# 87      8   30        com.google.android.youtube
# 88      8   31        com.google.android.youtube
# 89      8   32        com.google.android.youtube
# 90      8   33        com.google.android.youtube
# 91      8   34        com.google.android.youtube
# 92      8   35                      com.whatsapp
# 93      8   36        com.google.android.youtube
# 94      8   37        com.google.android.youtube
# 95      8   38        com.google.android.youtube
# 96      8   39        com.google.android.youtube
# 97      8   40        com.google.android.youtube
# 98      8   41        com.google.android.youtube
# 99      8   42        com.google.android.youtube
# 100     8   43        com.google.android.youtube
# 101     8   44        com.google.android.youtube
# 102     8   45        com.google.android.youtube
# 103     8   46        com.google.android.youtube
# 104     8   47        com.google.android.youtube
# 105     8   48             com.instagram.android
# 106     8   49        com.google.android.youtube
# 107     8   50        com.google.android.youtube
# 108     8   51             com.instagram.android
# 109     8   52        com.google.android.youtube
# 110     8   53        com.google.android.youtube
# 111     8   54        com.google.android.youtube
# 112     8   55        com.google.android.youtube
# 113     8   56        com.google.android.youtube
# 114     8   57        com.google.android.youtube
# 115     8   58        com.google.android.youtube
# 116     8   59        com.google.android.youtube
# 117     9    0        com.google.android.youtube
# 118     9    1        com.google.android.youtube
# 119     9    2        com.google.android.youtube
# 120     9    3        com.google.android.youtube
# 121     9    4        com.google.android.youtube
# 122     9    5        com.google.android.youtube
# 123     9    6            org.telegram.messenger
# 124     9    7                      com.whatsapp
# 125     9    8                      com.whatsapp
# 126     9    9        com.google.android.youtube
# 127     9   10        com.google.android.youtube
# 128     9   11        com.google.android.youtube
# 129     9   12        com.google.android.youtube
# 130     9   13        com.google.android.youtube
# 131     9   14        com.google.android.youtube
# 132     9   15        com.google.android.youtube
# 133     9   16        com.google.android.youtube
# 134     9   17        com.google.android.youtube
# 135     9   18                      com.duolingo
# 136     9   19            org.telegram.messenger
# 137     9   20                      com.duolingo
# 138     9   21        com.google.android.youtube
# 139     9   22        com.google.android.youtube
# 140     9   23        com.google.android.youtube
# 141     9   24        com.google.android.youtube
# 142     9   25        com.google.android.youtube
# 143     9   26        com.google.android.youtube
# 144     9   27        com.google.android.youtube
# 145     9   28        com.google.android.youtube
# 146     9   29        com.google.android.youtube
# 147     9   30        com.google.android.youtube
# 148     9   31        com.google.android.youtube
# 149     9   32        com.google.android.youtube
# 150     9   33        com.google.android.youtube
# 151     9   34        com.google.android.youtube
# 152     9   35        com.google.android.youtube
# 153     9   36        com.google.android.youtube
# 154     9   37        com.google.android.youtube
# 155     9   38        com.google.android.youtube
# 156     9   39        com.google.android.youtube
# 157     9   40        com.google.android.youtube
# 158     9   41        com.google.android.youtube
# 159     9   42        com.google.android.youtube
# 160     9   43        com.google.android.youtube
# 161     9   44        com.google.android.youtube
# 162     9   45        com.google.android.youtube
# 163     9   46        com.google.android.youtube
# 164     9   47             com.google.android.gm
# 165     9   48        com.google.android.youtube
# 166     9   49        com.google.android.youtube
# 167     9   50                      com.duolingo
# 168     9   51                      com.duolingo
# 169     9   52                      com.duolingo
# 170     9   53                      com.duolingo
# 171     9   54            org.telegram.messenger
# 172     9   55        com.google.android.youtube
# 173     9   56        com.google.android.youtube
# 174     9   57        com.google.android.youtube
# 175     9   58        com.google.android.youtube
# 176     9   59        com.google.android.youtube
# 177    10    0        com.google.android.youtube
# 178    10    1        com.google.android.youtube
# 179    10    2        com.google.android.youtube
# 180    10    3        com.google.android.youtube
# 181    10    4        com.google.android.youtube
# 182    10    5        com.google.android.youtube
# 183    10    6        com.google.android.youtube
# 184    10    7        com.google.android.youtube
# 185    10    8        com.google.android.youtube
# 186    10    9        com.google.android.youtube
# 187    10   10        com.google.android.youtube
# 188    10   11        com.google.android.youtube
# 189    10   12        com.google.android.youtube
# 190    10   13        com.google.android.youtube
# 191    10   14        com.google.android.youtube
# 192    10   15        com.google.android.youtube
# 193    10   16        com.google.android.youtube
# 194    10   17        com.google.android.youtube
# 195    10   18        com.google.android.youtube
# 196    10   19        com.google.android.youtube
# 197    10   20        com.google.android.youtube
# 198    10   21        com.google.android.youtube
# 199    10   22        com.google.android.youtube
# 200    10   23        com.google.android.youtube
# 201    10   24        com.google.android.youtube
# 202    10   25        com.google.android.youtube
# 203    10   26        com.google.android.youtube
# 204    10   27        com.google.android.youtube
# 205    10   28        com.google.android.youtube
# 206    10   29        com.google.android.youtube
# 207    10   30        com.google.android.youtube
# 208    10   31        com.google.android.youtube
# 209    10   32        com.google.android.youtube
# 210    10   33        com.google.android.youtube
# 211    10   34             com.instagram.android
# 212    10   35        com.google.android.youtube
# 213    10   36            org.telegram.messenger
# 214    10   37        com.google.android.youtube
# 215    10   38        com.google.android.youtube
# 216    10   39        com.google.android.youtube
# 217    10   40        com.google.android.youtube
# 218    10   41        com.google.android.youtube
# 219    10   42                com.android.chrome
# 220    10   43        com.google.android.youtube
# 221    10   44        com.google.android.youtube
# 222    10   45        com.google.android.youtube
# 223    10   46        com.google.android.youtube
# 224    10   47        com.google.android.youtube
# 225    10   48                      com.whatsapp
# 226    10   49        com.google.android.youtube
# 227    10   50        com.google.android.youtube
# 228    10   51                com.android.chrome
# 229    10   52                com.android.chrome
# 230    10   53             com.instagram.android
# 231    10   54             com.instagram.android
# 232    10   55            org.telegram.messenger
# 233    10   56             com.instagram.android
# 234    10   57        com.google.android.youtube
# 235    10   58        com.google.android.youtube
# 236    10   59        com.google.android.youtube
# 237    11    0        com.google.android.youtube
# 238    11    1            org.telegram.messenger
# 239    11    2            org.telegram.messenger
# 240    11    3            org.telegram.messenger
# 241    11    4        com.google.android.youtube
# 242    11    5        com.google.android.youtube
# 243    11    6        com.google.android.youtube
# 244    11    7        com.google.android.youtube
# 245    11    8        com.google.android.youtube
# 246    11    9            org.telegram.messenger
# 247    11   10            org.telegram.messenger
# 248    11   11        com.google.android.youtube
# 249    11   12        com.google.android.youtube
# 250    11   13            org.telegram.messenger
# 251    11   14            org.telegram.messenger
# 252    11   15            org.telegram.messenger
# 253    11   16            org.telegram.messenger
# 254    11   17            org.telegram.messenger
# 255    11   18        com.google.android.youtube
# 256    11   19        com.google.android.youtube
# 257    11   20        com.google.android.youtube
# 258    11   21        com.google.android.youtube
# 259    11   22        com.google.android.youtube
# 260    11   23        com.google.android.youtube
# 261    11   24        com.google.android.youtube
# 262    11   25        com.google.android.youtube
# 263    11   26        com.google.android.youtube
# 264    11   27            org.telegram.messenger
# 265    11   28        com.google.android.youtube
# 266    11   29       com.example.android.notepad
# 267    11   30       com.example.android.notepad
# 268    11   31        com.google.android.youtube
# 269    11   32        com.google.android.youtube
# 270    11   33        com.google.android.youtube
# 271    11   34        com.google.android.youtube
# 272    11   35             com.instagram.android
# 273    11   36             com.instagram.android
# 274    11   37             com.instagram.android
# 275    11   38             com.instagram.android
# 276    11   39             com.instagram.android
# 277    11   40             com.instagram.android
# 278    11   41             com.instagram.android
# 279    11   42             com.instagram.android
# 280    11   43             com.instagram.android
# 281    11   44        com.google.android.youtube
# 282    11   45        com.google.android.youtube
# 283    11   46        com.google.android.youtube
# 284    11   47        com.google.android.youtube
# 285    11   48        com.google.android.youtube
# 286    11   49        com.google.android.youtube
# 287    11   50        com.google.android.youtube
# 288    11   51                      com.whatsapp
# 289    11   52        com.google.android.youtube
# 290    11   53        com.google.android.youtube
# 291    11   54             com.google.android.gm
# 292    11   55        com.google.android.youtube
# 293    11   56        com.google.android.youtube
# 294    11   57        com.google.android.youtube
# 295    11   58        com.google.android.youtube
# 296    11   59        com.google.android.youtube
# 297    12    0            org.telegram.messenger
# 298    12    1        com.google.android.youtube
# 299    12    2        com.google.android.youtube
# 300    12    3        com.google.android.youtube
# 301    12    4                com.android.chrome
# 302    12    5                      com.whatsapp
# 303    12    6            org.telegram.messenger
# 304    12    7                      com.whatsapp
# 305    12    8             com.instagram.android
# 306    12    9             com.instagram.android
# 307    12   10             com.instagram.android
# 308    12   11             com.instagram.android
# 309    12   12            org.telegram.messenger
# 310    12   13            org.telegram.messenger
# 311    12   14        com.google.android.youtube
# 312    12   15        com.google.android.youtube
# 313    12   16        com.google.android.youtube
# 314    12   17                com.android.chrome
# 315    12   18                com.android.chrome
# 316    12   19                com.android.chrome
# 317    12   20            org.telegram.messenger
# 318    12   21        com.google.android.youtube
# 319    12   22        com.google.android.youtube
# 320    12   23        com.google.android.youtube
# 321    12   24        com.google.android.youtube
# 322    12   25        com.google.android.youtube
# 323    12   26        com.google.android.youtube
# 324    12   27            org.telegram.messenger
# 325    12   28                com.android.chrome
# 326    12   29             com.instagram.android
# 327    12   30                com.android.chrome
# 328    12   31                com.android.chrome
# 329    12   32                com.android.chrome
# 330    12   33                com.android.chrome
# 331    12   34                com.android.chrome
# 332    12   35                com.android.chrome
# 333    12   36                com.android.chrome
# 334    12   37                com.android.chrome
# 335    12   38                com.android.chrome
# 336    12   39                com.android.chrome
# 337    12   40                com.android.chrome
# 338    12   41                com.android.chrome
# 339    12   42                com.android.chrome
# 340    12   43                com.android.chrome
# 341    12   44      com.google.android.apps.docs
# 342    12   45             com.instagram.android
# 343    12   46             com.instagram.android
# 344    12   47             com.instagram.android
# 345    12   48             com.instagram.android
# 346    12   49                com.android.chrome
# 347    12   50                com.android.chrome
# 348    12   51        com.google.android.youtube
# 349    12   52        com.google.android.youtube
# 350    12   53        com.google.android.youtube
# 351    12   54        com.google.android.youtube
# 352    12   55        com.google.android.youtube
# 353    12   56        com.google.android.youtube
# 354    12   57        com.google.android.youtube
# 355    12   58        com.google.android.youtube
# 356    12   59        com.google.android.youtube
# 357    13    0        com.google.android.youtube
# 358    13    1        com.google.android.youtube
# 359    13    2        com.google.android.youtube
# 360    13    3        com.google.android.youtube
# 361    13    4        com.google.android.youtube
# 362    13    5        com.google.android.youtube
# 363    13    6                com.android.chrome
# 364    13    7                com.android.chrome
# 365    13    8        com.google.android.youtube
# 366    13    9        com.google.android.youtube
# 367    13   10                com.android.chrome
# 368    13   11                com.android.chrome
# 369    13   12        com.google.android.youtube
# 370    13   13        com.google.android.youtube
# 371    13   14            org.telegram.messenger
# 372    13   15        com.google.android.youtube
# 373    13   16        com.google.android.youtube
# 374    13   17        com.google.android.youtube
# 375    13   18                      com.whatsapp
# 376    13   19                      com.whatsapp
# 377    13   20                com.android.chrome
# 378    13   21                com.android.chrome
# 379    13   22             com.instagram.android
# 380    13   23             com.instagram.android
# 381    13   24             com.instagram.android
# 382    13   25             com.instagram.android
# 383    13   26             com.instagram.android
# 384    13   27             com.instagram.android
# 385    13   28            org.telegram.messenger
# 386    13   29            org.telegram.messenger
# 387    13   30             com.instagram.android
# 388    13   31             com.instagram.android
# 389    13   32             com.instagram.android
# 390    13   33                com.android.chrome
# 391    13   34                com.android.chrome
# 392    13   35                com.android.chrome
# 393    13   36                com.android.chrome
# 394    13   37                com.android.chrome
# 395    13   38                com.android.chrome
# 396    13   39                com.android.chrome
# 397    13   40                com.android.chrome
# 398    13   41                com.android.chrome
# 399    13   42                com.android.chrome
# 400    13   43        com.google.android.youtube
# 401    13   44        com.google.android.youtube
# 402    13   45        com.google.android.youtube
# 403    13   46        com.google.android.youtube
# 404    13   47        com.google.android.youtube
# 405    13   48        com.google.android.youtube
# 406    13   49                com.android.chrome
# 407    13   50                com.android.chrome
# 408    13   51                com.android.chrome
# 409    13   52                com.android.chrome
# 410    13   53                com.android.chrome
# 411    13   54                com.android.chrome
# 412    13   55                com.android.chrome
# 413    13   56                com.android.chrome
# 414    13   57                com.android.chrome
# 415    13   58                com.android.chrome
# 416    13   59                com.android.chrome
# 417    14    0                com.android.chrome
# 418    14    1                com.android.chrome
# 419    14    2            com.adobe.scan.android
# 420    14    3            com.adobe.scan.android
# 421    14    4            org.telegram.messenger
# 422    14    5            com.adobe.scan.android
# 423    14    6        com.google.android.youtube
# 424    14    7        com.google.android.youtube
# 425    14    8        com.google.android.youtube
# 426    14    9        com.google.android.youtube
# 427    14   10        com.google.android.youtube
# 428    14   11        com.google.android.youtube
# 429    14   12        com.google.android.youtube
# 430    14   13        com.google.android.youtube
# 431    14   14        com.google.android.youtube
# 432    14   15             com.instagram.android
# 433    14   16             com.android.gallery3d
# 434    14   17             com.instagram.android
# 435    14   18             com.instagram.android
# 436    14   19             com.instagram.android
# 437    14   20             com.instagram.android
# 438    14   21             com.instagram.android
# 439    14   22             com.instagram.android
# 440    14   23            org.telegram.messenger
# 441    14   24            org.telegram.messenger
# 442    14   25            org.telegram.messenger
# 443    14   26            org.telegram.messenger
# 444    14   27            org.telegram.messenger
# 445    14   28            org.telegram.messenger
# 446    14   29            org.telegram.messenger
# 447    14   30             com.instagram.android
# 448    14   31             com.instagram.android
# 449    14   32             com.instagram.android
# 450    14   33             com.instagram.android
# 451    14   34             com.instagram.android
# 452    14   35                com.android.chrome
# 453    14   36                com.android.chrome
# 454    14   37            org.telegram.messenger
# 455    14   38        com.google.android.youtube
# 456    14   39        com.google.android.youtube
# 457    14   40        com.google.android.youtube
# 458    14   50             com.android.deskclock
# 459    14   51                com.android.chrome
# 460    14   52                com.android.chrome
# 461    14   53                com.android.chrome
# 462    14   54                      com.whatsapp
# 463    14   55                com.android.chrome
# 464    14   56                com.android.chrome
# 465    14   57                com.android.chrome
# 466    14   58                com.android.chrome
# 467    14   59                com.android.chrome
# 468    15    0                      com.whatsapp
# 469    15    1                      com.whatsapp
# 470    15    2            org.telegram.messenger
# 471    15    3            org.telegram.messenger
# 472    15    4                      com.whatsapp
# 473    15    5                      com.whatsapp
# 474    15    6                      com.whatsapp
# 475    15    7                      com.whatsapp
# 476    15    8        com.google.android.youtube
# 477    15    9        com.google.android.youtube
# 478    15   10        com.google.android.youtube
# 479    15   11        com.google.android.youtube
# 480    15   12        com.google.android.youtube
# 481    15   13        com.google.android.youtube
# 482    15   14        com.google.android.youtube
# 483    15   15            org.telegram.messenger
# 484    15   16        com.google.android.youtube
# 485    15   17        com.google.android.youtube
# 486    15   18        com.google.android.youtube
# 487    15   19        com.google.android.youtube
# 488    15   20        com.google.android.youtube
# 489    15   21        com.google.android.youtube
# 490    15   22        com.google.android.youtube
# 491    15   23        com.google.android.youtube
# 492    15   24        com.google.android.youtube
# 493    15   25        com.google.android.youtube
# 494    15   26        com.google.android.youtube
# 495    15   27        com.google.android.youtube
# 496    15   28        com.google.android.youtube
# 497    15   29        com.google.android.youtube
# 498    15   30        com.google.android.youtube
# 499    15   31        com.google.android.youtube

# %%
df[df['application'] == 'com.google.android.youtube']
# Out:
#        userid                 application             time  min  sec  hour
# 7787      234  com.google.android.youtube  14:21:59.757000   21   59    14
# 10176     234  com.google.android.youtube  20:34:08.612000   34    8    20
# 10177     234  com.google.android.youtube  20:34:03.576000   34    3    20
# 10178     234  com.google.android.youtube  20:33:58.571000   33   58    20
# 10179     234  com.google.android.youtube  20:33:53.613000   33   53    20
# ...       ...                         ...              ...  ...  ...   ...
# 59680     234  com.google.android.youtube  12:01:27.429000    1   27    12
# 59681     234  com.google.android.youtube  12:01:22.412000    1   22    12
# 59682     234  com.google.android.youtube  12:01:17.477000    1   17    12
# 59683     234  com.google.android.youtube  12:01:12.310000    1   12    12
# 59684     234  com.google.android.youtube  12:01:07.291000    1    7    12
#
# [7799 rows x 6 columns]

# %% [markdown]
# !! attenzione c'è un app senza nome che è quella piu usata

# %%
df.value_counts('application')
# Out:
# application
#                                        23190
# com.huawei.android.launcher            13816
# com.google.android.youtube              7799
# com.instagram.android                   4911
# org.telegram.messenger                  3015
# com.android.chrome                      2090
# com.whatsapp                            1916
# com.riotgames.legendsofruneterra         830
# it.unitn.disi.witmee.sensorlog           715
# com.android.incallui                     666
# com.duolingo                             296
# com.google.android.apps.docs             216
# com.adobe.scan.android                   131
# com.google.android.gm                    117
# com.example.android.notepad               86
# com.roidapp.photogrid                     69
# com.android.deskclock                     64
# com.android.gallery3d                     49
# com.habitrpg.android.habitica             49
# com.android.settings                      28
# com.android.contacts                      20
# com.android.vending                       17
# com.google.android.packageinstaller        4
# com.huawei.hwid                            3
# com.huawei.android.hwouc                   2
# it.ministerodellasalute.immuni             2
# com.hicloud.android.clone                  1
# com.huawei.android.tips                    1
# com.huawei.systemmanager                   1
# com.google.android.gms                     1
# com.flipd.app                              1
# com.android.systemui                       1
# dtype: int64

# %% [markdown]
# ## Screen

# %%
df = pd.read_sql_query("select count(status) from screen group by date" , db.connection)

# %%
df
# Out:
#     count(status)
# 0              78
# 1              38
# 2            1386
# 3          107014
# 4          157929
# 5          387084
# 6          477350
# 7          462168
# 8          643395
# 9          666508
# 10         592301
# 11         639965
# 12         487451
# 13         457304
# 14         468658
# 15         511371
# 16         470432
# 17         483224
# 18         477169
# 19         451449
# 20         395342
# 21         424641
# 22         517571
# 23         456155
# 24         419365
# 25         442002
# 26         384237
# 27         344658
# 28         328554
# 29         366641
# 30         375749
# 31         355116
# 32         360576
# 33         306638
# 34          88016
# 35          33136
# 36          28630
# 37          20008
# 38            691

# %%
df[df['date'] == '2020-11-23']
# Out:
#                        timestamp        date             time  userid  \
# 2034  2020-11-23 23:43:17.249000  2020-11-23  23:43:17.249000     233
# 2035  2020-11-23 23:12:22.085000  2020-11-23  23:12:22.085000     233
# 2036  2020-11-23 23:10:39.131000  2020-11-23  23:10:39.131000     233
# 2037  2020-11-23 22:48:17.784000  2020-11-23  22:48:17.784000     233
# 2038  2020-11-23 22:23:17.318000  2020-11-23  22:23:17.318000     233
# ...                          ...         ...              ...     ...
# 2119  2020-11-23 04:05:56.842000  2020-11-23  04:05:56.842000     233
# 2120  2020-11-23 01:14:43.103000  2020-11-23  01:14:43.103000     233
# 2121  2020-11-23 01:14:33.245000  2020-11-23  01:14:33.245000     233
# 2122  2020-11-23 01:14:33.232000  2020-11-23  01:14:33.232000     233
# 2123  2020-11-23 00:27:43.487000  2020-11-23  00:27:43.487000     233
#
#           status
# 2034  SCREEN_OFF
# 2035  SCREEN_OFF
# 2036   SCREEN_ON
# 2037  SCREEN_OFF
# 2038  SCREEN_OFF
# ...          ...
# 2119   SCREEN_ON
# 2120  SCREEN_OFF
# 2121   SCREEN_ON
# 2122  SCREEN_OFF
# 2123   SCREEN_ON
#
# [90 rows x 5 columns]

# %% [markdown]
# ## Location
